# %%
import pandas as pd
import matplotlib.pyplot as plt
# data = pd.read_csv("./ablation_atari_freeway.csv")
data = pd.read_csv("./ablation_pool_size_0.csv")
ax = data.plot(x='pool_size',y='performance',kind='scatter')
# ax.axhline(y=0.77, color='green', linestyle='--', label=f'y = previous sota')
ax.axhline(y=0.42, color='green', linestyle='--', label=f'y = previous sota')
ax.axhline(y=0.45, color='red', linestyle='--', label=f'y = best fusenet')
# ax.axhline(y=0.78, color='red', linestyle='--', label=f'y = best fusenet')
ax.legend()
ax.set_title("MetaWorld PoolSize Ablation - Performance seed = 0")
# data.plot(x='pool_size',y='forward_transfer')
# Out:
# Text(0.5, 1.0, 'MetaWorld PoolSize Ablation - Performance seed = 0')

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("./ablation_atari_freeway.csv")
ax = data.plot(x='pool_size',y='performance',kind='scatter')
ax.axhline(y=0.77, color='green', linestyle='--', label=f'y = previous sota')
ax.axhline(y=0.7867, color='red', linestyle='--', label=f'y = best fusenet')
ax.legend()
ax.set_title("Freeway PoolSize Ablation - Performance")
# ax = data.plot(x='pool_size',y='fwt',kind='scatter')
# ax.axhline(y=0.7287, color='green', linestyle='--', label=f'y = previous sota')
# ax.axhline(y=0.7437, color='red', linestyle='--', label=f'y = best fusenet')
# ax.legend()
# ax.set_title("Freeway PoolSize Ablation - Forward Transfer")
# data.plot(x='pool_size',y='forward_transfer')
# Out:
# Text(0.5, 1.0, 'Freeway PoolSize Ablation - Performance')

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("./ablation_atari_space.csv")
ax = data.plot(x='pool_size',y='performance',kind='scatter')
ax.axhline(y=0.9536, color='green', linestyle='--', label=f'y = previous sota')
ax.axhline(y=0.9718, color='red', linestyle='--', label=f'y = best fusenet')
ax.legend()
ax.set_title("Space PoolSize Ablation - Performance")
ax = data.plot(x='pool_size',y='fwt',kind='scatter')
ax.axhline(y=0.7058, color='green', linestyle='--', label=f'y = previous sota')
ax.axhline(y=0.7398, color='red', linestyle='--', label=f'y = best fusenet')
ax.legend()
ax.set_title("Space PoolSize Ablation - Forward Transfer")
# Out:
# Text(0.5, 1.0, 'Space PoolSize Ablation - Forward Transfer')
